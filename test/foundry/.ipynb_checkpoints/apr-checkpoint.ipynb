# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = []
b = []
c = []

with open('kek.logs', 'r') as f:
    z = f.readlines()
    for i in range(len(z)):
        v = str(z[i]).split(' ')
        a.append(int(v[0]) / 10**6)
        b.append(int(v[1].split('\n')[0]))
        
        tms = 12 * len(z)
        c.append(100 * (int(v[0]) - 10**8) * tms / (i + 1) / 10**8)
        
plt.plot(a)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

plt.plot(b)
plt.show()

plt.plot(c)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 15
#      12         tms = 12 * len(z)
#      13         c.append(100 * (int(v[0]) - 10**8) * tms / (i + 1) / 10**8)
# ---> 15 plt.plot(a, ylabel='usd')
#      16 plt.show()
#      18 plt.plot(b)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
# ...
